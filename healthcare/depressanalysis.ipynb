# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import matplotlib as mpl
import numpy as np
import pandas as pd
import copy
warnings.filterwarnings(action='ignore')

from matplotlib import font_manager, rc
font_manager.get_fontconfig_fonts()
font_name = font_manager.FontProperties(fname='C:\windows\Fonts\H2GTRM.TTF').get_name()

#plt.rcParams["font.family"] = font_name
rc('font', family=font_name)
mpl.rcParams['axes.unicode_minus'] = False

# %matplotlib inline
plt.rcParams['font.size']=12

import pandas as pd
import numpy as np
import eli5
import shap
import copy

from eli5.sklearn import PermutationImportance
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, roc_curve, confusion_matrix
import numpy as np
from sklearn.metrics import classification_report

from sklearn.model_selection import KFold, cross_val_score, cross_val_predict
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.preprocessing import MinMaxScaler, StandardScaler, MaxAbsScaler, Normalizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

# %%
data['나이'].plot(kind='hist')
plt.show()
data['성별'].value_counts().plot.pie(autopct="%.2f%%")
plt.show()
plt.bar(['여성','남성'],data['성별'].value_counts())
# Out:
# <BarContainer object of 2 artists>

# %%
drop_art=data.drop(index=data[artadt==1].index).copy()

# %%
data['우울증'].value_counts().plot(kind='pie',autopct='%.2f%%')
plt.show()
drop_art['우울증'].value_counts().plot(kind='pie',autopct='%.2f%%')
# Out:
# <AxesSubplot:ylabel='우울증'>

# %%
only_depre = data.drop(index=data[artadt==0].index).copy()

# %%
only_depre['우울증'][artadt==1]=0

# %%
print(only_depre['우울증'].value_counts(), '\n 0은 ART, 1은 ADT ')
only_depre['우울증'].value_counts().plot(kind='pie',autopct='%.2f%%')
# Out:
# 1    47
# 0    40
# Name: 우울증, dtype: int64
#  0은 ART, 1은 ADT
# <AxesSubplot:ylabel='우울증'>

# %%
from scipy.stats import ttest_ind, shapiro, mannwhitneyu, levene, kstest, f_oneway
test_df = data.iloc[:,2:].drop(columns=['나이','성별'])

Cat1 = test_df[test_df['우울증']==0]
Cat2 = test_df[test_df['우울증']==1]

cat1 = test_df[artadt==0]
cat2 = test_df[artadt==1]
cat3 = test_df[artadt==2]
print(len(cat1),len(cat2),len(cat3))
for column in test_df.columns.to_list()[:-1]:
    fig,ax = plt.subplots(1,2,figsize=(15,5))
    plt.suptitle('{} boxplot'.format(column))
    ax[0].boxplot((Cat1[column].to_numpy(),Cat2[column].to_numpy()),sym="o", labels=["대조군","질환군"])
    ax[1].boxplot((cat1[column].to_numpy(),cat2[column].to_numpy(),cat3[column].to_numpy()),sym="o", labels=["대조군","ART","ADT"])
    plt.show()
    print("\n T-test-statistic : %f \n p-value : %f"%ttest_ind(Cat1[column], Cat2[column]),end='\n\n')
    print("\n 대조군 Shapiro-Wilk-statistic : %f \n p-value : %f"%shapiro(Cat1[column]),end='\n\n')
    print("\n 질환군 Shapiro-Wilk-statistic : %f \n p-value : %f"%shapiro(Cat2[column]),end='\n\n')
    print("\n Mann-Whitney-statistic : %f \n p-value : %f"%mannwhitneyu(Cat1[column], Cat2[column]),end='\n\n')
    print("\n Levene-statistic : %f \n p-value : %f"%levene(Cat1[column], Cat2[column]),end='\n\n')
    print("\n 대조군 Kolmogorov-Smirnov -statistic : %f \n p-value : %f"%kstest(Cat1[column],'norm'),end='\n\n')
    print("\n 질환군 Kolmogorov-Smirnov -statistic : %f \n p-value : %f"%kstest(Cat2[column],'norm'),end='\n\n')
    print('==============================')
    print("\n F_oneway-statistic : %f \n p-value : %f"%f_oneway(cat1[column], cat2[column], cat3[column]),end='\n\n')
# Out:
# 66 40 47
#  T-test-statistic : -1.171783
#  p-value : 0.243130
#
#
#  대조군 Shapiro-Wilk-statistic : 0.990713
#  p-value : 0.905784
#
#
#  질환군 Shapiro-Wilk-statistic : 0.965413
#  p-value : 0.019924
#
#
#  Mann-Whitney-statistic : 2638.000000
#  p-value : 0.195864
#
#
#  Levene-statistic : 3.680613
#  p-value : 0.056936
#
#
#  대조군 Kolmogorov-Smirnov -statistic : 1.000000
#  p-value : 0.000000
#
#
#  질환군 Kolmogorov-Smirnov -statistic : 1.000000
#  p-value : 0.000000
#
# ...
#
#  F_oneway-statistic : 0.682188
#  p-value : 0.507071
#  T-test-statistic : 3.225128
#  p-value : 0.001544
#
#
#  대조군 Shapiro-Wilk-statistic : 0.984689
#  p-value : 0.591628
#
#
#  질환군 Shapiro-Wilk-statistic : 0.901648
#  p-value : 0.000007
#
#
#  Mann-Whitney-statistic : 1734.000000
#  p-value : 0.000014
#
#
#  Levene-statistic : 1.138692
#  p-value : 0.287632
#
#
#  대조군 Kolmogorov-Smirnov -statistic : 1.000000
#  p-value : 0.000000
#
#
#  질환군 Kolmogorov-Smirnov -statistic : 1.000000
#  p-value : 0.000000
#
# ...
#
# ...

# %%
import seaborn as sns
plt.figure(figsize=(15,15))
sns.heatmap(data = test_df.corr(), annot=True,fmt = '.2f', linewidths=.5, cmap='cool')
# Out:
# <AxesSubplot:>

# %%
### RAW 데이터 불러오기 ###
# KS모델의 KNN 모델

### train/test ###
from sklearn.model_selection import train_test_split

#X = data.iloc[:,2:].drop(columns=['우울증','나이','성별'])
#X = drop_art.iloc[:,2:].drop(columns=['우울증','나이','성별'])
X = only_depre.iloc[:,2:].drop(columns=['우울증','나이','성별'])

#y = data.loc[:, '우울증'].values
#y = drop_art.loc[:, '우울증'].values
y = only_depre.loc[:, '우울증'].values

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.222, random_state=42)

### normalization ###
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x_ = scaler.fit_transform(X)
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

### KNN classification ###
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.metrics import classification_report
knn = KNeighborsClassifier(11)
knn.fit(x_train,y_train)
'''
estimator_KNN = KNeighborsClassifier()
parameters_KNN = [{
            'n_neighbors': range(1,20),
            'p': (1,2),
            'weights': ('uniform', 'distance'),
            'metric': ('minkowski', 'chebyshev','euclidean','manhattan'),
            'algorithm':('auto','kd_tree','ball_tree','brute')      
            }
            ,{   #mahalanobis, seuclidean 때문에 추가
             'n_neighbors': range(1,20),
             'leaf_size': range(20,40),
             'p': (1,2),
             'weights': ('uniform', 'distance'),
             'metric': ('mahalanobis','seuclidean'),
             'metric_params':[{'V':np.cov(X)}]
             }]
        
# GridSearchCV 파라미터 탐색
kfold = KFold(n_splits=3, shuffle=True, random_state=0)
knn = GridSearchCV(
            estimator=estimator_KNN,
            param_grid=parameters_KNN,
            scoring = 'f1',  #'f1','roc_auc','accuracy'
            cv = kfold
        )
knn.fit(x_train,y_train)
print('최고 평균 정확도 : ', knn.best_score_)
print('최고 파라미터 : ', knn.best_params_)    
'''
y_pred = knn.predict(x_train)
print("----- train score -----")
print(knn.score(x_train, y_train))
print('f2 score : ', metrics.fbeta_score(y_train, y_pred, beta=2))
y_pred = knn.predict(x_test)
print("----- test score -----")
print(knn.score(x_test, y_test))
print('f1 score : ', metrics.f1_score(y_test, y_pred))
print('f2 score : ', metrics.fbeta_score(y_test, y_pred, beta=2), end='\n\n')
print(classification_report(y_test, y_pred, target_names=['Disease 0', 'Disease 1']))
### validataion ###
feature = scaler.fit_transform(X)
y_pred = knn.predict(feature)
from sklearn.metrics import confusion_matrix
print("----- confusion matrix -----")
print(confusion_matrix(y, y_pred))
print('accuracy', metrics.accuracy_score(y, y_pred))
print('precision', metrics.precision_score(y, y_pred))
print('recall', metrics.recall_score(y, y_pred))
print('f1 score : ', metrics.f1_score(y, y_pred))
print('f2 score : ', metrics.fbeta_score(y, y_pred, beta=2))



## 랜덤포레스트 변수 중요도 평가 결과 시각화 (MDI)


## 모델 파라미터 탐색 - 시간이 걸리는 과정이므로 파라미터 결정된 후에는 주석처리하여 재실행되지 않도록함
print("----- Random Forest(MDI) -----")
rf_model = RandomForestClassifier()
rf_param = {
    'n_estimators':[500, 800],
    'max_depth':[5,6,8,10],
    'min_samples_split':[10,20,30],
    'random_state':[0,1]
}
rf_grid = GridSearchCV(rf_model, param_grid=rf_param, scoring='accuracy')
rf_grid.fit(x_train, y_train)
print('최고 평균 정확도 : ', rf_grid.best_score_)
print('최고 파라미터 : ', rf_grid.best_params_,end='\n\n')

## 랜덤포레스트 모델 구축
from sklearn import metrics
model = RandomForestClassifier(max_depth=5, min_samples_split=10, n_estimators=500, random_state=0)
model.fit(x_train, y_train)
print('train 정확도', model.score(x_train, y_train))

pred = model.predict(x_test)
print('test 정확도: ', accuracy_score(y_test, pred))
print(classification_report(y_test, pred, target_names=['Disease 0', 'Disease 1']))

y_pred = model.predict(X)
print('all data 정확도: ', accuracy_score(y, y_pred))
print('f1 score : ', metrics.f1_score(y, y_pred))
print('f2 score : ', metrics.fbeta_score(y, y_pred, beta=2))
import matplotlib.pyplot as plt
importance = pd.DataFrame({'feature':X.columns, 'importance':model.feature_importances_}).sort_values(by='importance', ascending=False)
print(importance)

plt.figure(figsize=(70,10))
plt.title('Feature Importances(MDI)')
plt.bar(x=importance['feature'], height=importance['importance'])
plt.xticks(fontsize = 8)
plt.show()

#KJ# permutation importance 변수 중요도평가
from sklearn.inspection import permutation_importance
result=permutation_importance(knn.fit(x_train, y_train), x_test, y_test, n_repeats=10, random_state=0)

importance = pd.DataFrame({'feature':X.columns, 'importance':result.importances_std}).sort_values(by='importance', ascending=False)
print(importance)

plt.figure(figsize=(70,10))
plt.title('Feature Importances(RF-PI)')
plt.bar(x=importance['feature'], height=importance['importance'])
plt.xticks(fontsize = 8)
plt.show()


## Permutaion Importance 변수 중요도 체크
import eli5
from eli5.sklearn import PermutationImportance
import matplotlib.pyplot as plt
import warnings
import matplotlib as mpl
warnings.filterwarnings(action='ignore')

from matplotlib import font_manager, rc
font_manager.get_fontconfig_fonts()
font_name = font_manager.FontProperties(fname='C:\windows\Fonts\H2GTRM.TTF').get_name()
#plt.rcParams["font.family"] = font_name
rc('font', family=font_name)
mpl.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.size']=10

perm = PermutationImportance(knn, scoring='f1', random_state=0).fit(x_test, y_test)
print('F1:', perm.scores_)
#eli5.show_weights(perm, feature_names = X.columns.tolist(), show_feature_values=True) # Permutation Importance

# eli5 변수 중요도 출력하기
weight = eli5.explain_weights_df(perm, feature_names = X.columns.tolist())
weight_col = weight.feature
importance = pd.DataFrame({'feature' : weight_col, 
                           'importance' : weight.weight[:20]}).sort_values(by='importance', ascending=False)

plt.figure(figsize=(50,20))
plt.title("Feature importances(PI)2")
plt.bar(x=importance['feature'], height=importance['importance'])
plt.xticks(fontsize=10)
plt.show()


## SHAP value
import shap

shap.initjs()
x_test_ = pd.DataFrame(x_test,columns=X.columns)

explainer = shap.KernelExplainer(knn.predict, x_test_)
shap_values = explainer.shap_values(x_test_)
shap.summary_plot(shap_values, x_test_,plot_type='bar')
# Out:
# ----- train score -----
# 0.8059701492537313
# f2 score :  0.9068627450980392
# ----- test score -----
# 0.8
# f1 score :  0.75
# f2 score :  0.75
#
#               precision    recall  f1-score   support
#
#    Disease 0       0.83      0.83      0.83        12
#    Disease 1       0.75      0.75      0.75         8
#
#     accuracy                           0.80        20
#    macro avg       0.79      0.79      0.79        20
# weighted avg       0.80      0.80      0.80        20
#
# ----- confusion matrix -----
# [[30 10]
#  [ 4 43]]
# accuracy 0.8390804597701149
# precision 0.8113207547169812
# recall 0.9148936170212766
# f1 score :  0.8600000000000001
# f2 score :  0.8921161825726139
# ----- Random Forest(MDI) -----
# 최고 평균 정확도 :  0.7912087912087913
# 최고 파라미터 :  {'max_depth': 6, 'min_samples_split': 10, 'n_estimators': 500, 'random_state': 1}
#
# train 정확도 1.0
# test 정확도:  0.85
#               precision    recall  f1-score   support
#
# ...

# %%
feature = data.iloc[:,2:].drop(columns=['성별','나이']).copy()
#feature = drop_art.iloc[:,2:].drop(columns=['나이','성별'])
#feature = only_depre.iloc[:,2:].drop(columns=['나이','성별'])
test_features=feature.copy()
colname = feature.columns
y = data.loc[:, '우울증'].values
#feature['우울증'] = knn.predict(x_)

### PCA ###
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
scaler = MinMaxScaler()
feature = scaler.fit_transform(feature.values)

pca = PCA(n_components=2)
feature_pca = pca.fit_transform(feature_pca)

print("\n----- data pca -----") 
print('설명비율 : ', pca.explained_variance_ratio_)
print('누적설명비율 : ', np.cumsum(pca.explained_variance_ratio_)[1])

### train/test ###
'''
SVM을 진행하기 위한 데이터 생성. 
70:30 비율로 train/test set을 나눈다.
'''
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(feature_pca,y, test_size=0.222, random_state=0)
print("----- train shape -----")
print(x_train.shape, y_train.shape)
print(pd.Series(y_train).value_counts())
print("----- test shape -----")
print(x_test.shape, y_test.shape)
print(pd.Series(y_test).value_counts(), end='\n\n')



### linear SVM ###
'''
두 집단을 나누는 직선을 만드는 모델.
train 과 test 에서 오분류된 사람이 있는지 점수로 평가한다.
단 svm model은 예측이 목적이 아닌 직선을 기준으로 지수화가 목적이기 때문에 오분류된 사람없이 100% 분류가 잘 되는 것이 좋음. 
'''
from sklearn.svm import LinearSVC
model = LinearSVC()
svm_model = model.fit(x_train, y_train)

print("====== SVM ======\n")
coef = model.coef_[0]
intercept = model.intercept_[0]
print('계수 : ', coef)
print('상수 : ', intercept)

print("----- train score -----")
y_pred = model.predict(x_train)
print('train 점수 : ', model.score(x_train, y_train))
print('recall : ', metrics.recall_score(y_train, y_pred))
print('f1 score : ', metrics.f1_score(y_train, y_pred))
print('f2 score : ', metrics.fbeta_score(y_train, y_pred, beta=2))

print("----- test score -----")
y_pred = model.predict(x_test)
print('test 점수 : ', model.score(x_test, y_test))
print('recall : ', metrics.recall_score(y_test, y_pred))
print('f1 score : ', metrics.f1_score(y_test, y_pred))
print('f2 score : ', metrics.fbeta_score(y_test, y_pred, beta=2))
print(classification_report(y_test, y_pred, target_names=['Disease 0', 'Disease 1']))



### visualization ###
'''
train 과 test 데이터 점과 svm 결과 직선을 시각화로 확인한다.
'''
import matplotlib.pyplot as plt

## train
mask = y_train == 0
plt.scatter(x_train[mask, 0], x_train[mask, 1], c='b')
plt.scatter(x_train[~mask, 0], x_train[~mask, 1], c='r')
x = np.arange(-0.8, 0.9, 0.1)
y_tmp = -(intercept/coef[1]) - (coef[0]/coef[1])*x
plt.plot(x, y_tmp)
plt.xlabel("pc1")
plt.ylabel("pc2")
plt.ylim(-2,2)
plt.show()

## test
mask = y_test == 0
plt.scatter(x_test[mask, 0], x_test[mask, 1], c='b')
plt.scatter(x_test[~mask, 0], x_test[~mask, 1], c='r')
x = np.arange(-0.8, 0.9, 0.1)
y_tmp = -(intercept/coef[1]) - (coef[0]/coef[1])*x
plt.plot(x, y_tmp)
plt.xlabel("pc1")
plt.ylabel("pc2")
plt.ylim(-2,2)
plt.show()
# 여기까지 그래프 출력

### Plane : ax+by+cz+d=0 ###
a = coef[0]
b = coef[1]
d = intercept

import math
def distance(x,y):
    up = abs(a*x + b*y +d)
    down = math.sqrt(a**2 + b**2 )
    return up/down

feature_pca = pd.DataFrame(feature_pca, columns=['pc1','pc2'])
dist = feature_pca.apply(lambda x:distance(x['pc1'], x['pc2']), axis=1)

idx0 = feature_pca[y == 0].index   ## 정상인 인덱스
idx1 = feature_pca[y == 1].index   ## 질환자 인덱스

from sklearn.preprocessing import StandardScaler
Sscaler = StandardScaler()
dist0 = Sscaler.fit_transform(np.array(dist[idx0]).reshape(-1,1))
dist1 = Sscaler.fit_transform(np.array(dist[idx1]).reshape(-1,1))
print(Sscaler.mean_)
print(Sscaler.var_)
print(len(idx0), len(idx1))

def level(x):
    if x > 0:    #0.84
        result=1
    else:
        result=0
    return result

# 기존의 5개 clustering을 2개로 줄임.
dist0_result = list(map(lambda x: level(x), dist0))
dist1_result = list(map(lambda x: level(x), dist1))


print("건강인 : ",dist0_result.count(0))
print("일반인 : ",dist0_result.count(1))

print("경증 질환자 : ",dist1_result.count(0))
print("중증 질환자 : ",dist1_result.count(1))
# Out:
# ----- data pca -----
# 설명비율 :  [0.46737076 0.41591104]
# 누적설명비율 :  0.8832818024986703
# ----- train shape -----
# (119, 2) (119,)
# 1    67
# 0    52
# dtype: int64
# ----- test shape -----
# (34, 2) (34,)
# 1    20
# 0    14
# dtype: int64
#
# ====== SVM ======
#
# 계수 :  [ 1.81106777 -0.76981732]
# 상수 :  0.1467866959800172
# ----- train score -----
# train 점수 :  1.0
# recall :  1.0
# f1 score :  1.0
# f2 score :  1.0
# ----- test score -----
# test 점수 :  1.0
# recall :  1.0
# f1 score :  1.0
# f2 score :  1.0
#               precision    recall  f1-score   support
#
#    Disease 0       1.00      1.00      1.00        14
#    Disease 1       1.00      1.00      1.00        20
#
#     accuracy                           1.00        34
#    macro avg       1.00      1.00      1.00        34
# weighted avg       1.00      1.00      1.00        34
# [0.51259358]
# [0.00079711]
# 66 87
# 건강인 :  28
# 일반인 :  38
# 경증 질환자 :  46
# 중증 질환자 :  41

# %%
from scipy.stats import ttest_ind, shapiro, mannwhitneyu, levene, kstest, f_oneway
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.linear_model import LogisticRegression

#pair_df = data.iloc[:,2:].drop(columns=['나이','성별'])

Cat1 = pair_data[pair_data['ADT/ART']==1]
Cat2 = pair_data[pair_data['ADT/ART']==0]

for column in pair_data.columns.to_list()[5:-1]:
    X = np.array(pair_data[column]).reshape(-1,1)
    y = pair_data.loc[:, 'ADT/ART'].values
    x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.333, random_state=42)
    model = KNeighborsClassifier()

    model.fit(X,y)
    y_score=model.predict_proba(X)
    fpr, tpr, _ = roc_curve(y, y_score[:,1])

    fig,ax = plt.subplots(1,2,figsize=(15,5))
    plt.suptitle('{} boxplot'.format(column))
    ax[0].boxplot((Cat1[column].to_numpy(),Cat2[column].to_numpy()),sym="o", labels=["ADT","ART"])
    ax[1].step(fpr, tpr, color='darkorange',lw=2,label='ROC curve')
    plt.show()
    
    print("\n ROC Curve : %f \n "%roc_auc_score(y, y_score[:,1]),end='\n\n')    
    print("\n T-test-statistic : %f \n p-value : %f"%ttest_ind(Cat1[column], Cat2[column]),end='\n\n')
    print("\n 대조군 Shapiro-Wilk-statistic : %f \n p-value : %f"%shapiro(Cat1[column]),end='\n\n')
    print("\n 질환군 Shapiro-Wilk-statistic : %f \n p-value : %f"%shapiro(Cat2[column]),end='\n\n')
    print("\n Mann-Whitney-statistic : %f \n p-value : %f"%mannwhitneyu(Cat1[column], Cat2[column]),end='\n\n')
    print("\n Levene-statistic : %f \n p-value : %f"%levene(Cat1[column], Cat2[column]),end='\n\n')
#   print("\n 대조군 Kolmogorov-Smirnov -statistic : %f \n p-value : %f"%kstest(Cat1[column],'norm'),end='\n\n')
#   print("\n 질환군 Kolmogorov-Smirnov -statistic : %f \n p-value : %f"%kstest(Cat2[column],'norm'),end='\n\n')
# Out:
#  ROC Curve : 0.748521
#
#
#
#  T-test-statistic : 1.083540
#  p-value : 0.289335
#
#
#  대조군 Shapiro-Wilk-statistic : 0.964676
#  p-value : 0.823714
#
#
#  질환군 Shapiro-Wilk-statistic : 0.945662
#  p-value : 0.534240
#
#
#  Mann-Whitney-statistic : 70.000000
#  p-value : 0.236394
#
#
#  Levene-statistic : 0.020674
#  p-value : 0.886872
#  ROC Curve : 0.733728
#
#
#
#  T-test-statistic : 2.533611
#  p-value : 0.018234
#
#
#  대조군 Shapiro-Wilk-statistic : 0.960849
#  p-value : 0.766723
#
#
#  질환군 Shapiro-Wilk-statistic : 0.951382
#  p-value : 0.619376
#
#
#  Mann-Whitney-statistic : 39.000000
#  p-value : 0.010508
#
#
#  Levene-statistic : 2.668759
#  p-value : 0.115387
#  ROC Curve : 0.730769
#
#
#
#  T-test-statistic : 1.580463
#  p-value : 0.127091
#
#
#  대조군 Shapiro-Wilk-statistic : 0.962662
#  p-value : 0.794166
#
#
#  질환군 Shapiro-Wilk-statistic : 0.904893
#  p-value : 0.156087
#
#
#  Mann-Whitney-statistic : 61.000000
#  p-value : 0.119102
#
#
#  Levene-statistic : 0.000011
# ...

# %%
from sklearn.model_selection import train_test_split


X = pair_data.iloc[:,5:].drop(columns=['ADT/ART'])
y = pair_data.loc[:, 'ADT/ART'].values

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

### normalization ###
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

### KNN classification ###
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.metrics import classification_report

estimator_KNN = KNeighborsClassifier()
parameters_KNN = {
            'n_neighbors': range(1,20),
            'leaf_size': range(20,40),
            'p': (1,2),
            'weights': ('uniform', 'distance'),
            'metric': ('minkowski', 'chebyshev','euclidean','manhattan'),
            'algorithm':('auto','kd_tree','ball_tree','brute')      
            }

        
# GridSearchCV 파라미터 탐색
kfold = KFold(n_splits=3, shuffle=True, random_state=0)
knn = GridSearchCV(
            estimator=estimator_KNN,
            param_grid=parameters_KNN,
            scoring = 'f1',  #'f1','roc_auc','accuracy'
            cv = kfold
        )
knn.fit(x_train,y_train)
print('최고 평균 정확도 : ', knn.best_score_)
print('최고 파라미터 : ', knn.best_params_)    

y_pred = knn.predict(x_train)
print("----- train score -----")
print(knn.score(x_train, y_train))
print('f2 score : ', metrics.fbeta_score(y_train, y_pred, beta=2))
y_pred = knn.predict(x_test)
print("----- test score -----")
print(knn.score(x_test, y_test))
print('f1 score : ', metrics.f1_score(y_test, y_pred))
print('f2 score : ', metrics.fbeta_score(y_test, y_pred, beta=2), end='\n\n')
print(classification_report(y_test, y_pred, target_names=['Disease 0', 'Disease 1']))
### validataion ###
feature = scaler.fit_transform(X)
y_pred = knn.predict(feature)

from sklearn.metrics import confusion_matrix
print("----- confusion matrix -----")
print(confusion_matrix(y, y_pred))
print('accuracy', metrics.accuracy_score(y, y_pred))
print('precision', metrics.precision_score(y, y_pred))
print('recall', metrics.recall_score(y, y_pred))
print('f1 score : ', metrics.f1_score(y, y_pred))
print('f2 score : ', metrics.fbeta_score(y, y_pred, beta=2), end='\n\n')
# Out:
# 최고 평균 정확도 :  0.8690476190476191
# 최고 파라미터 :  {'algorithm': 'auto', 'leaf_size': 20, 'metric': 'chebyshev', 'n_neighbors': 8, 'p': 1, 'weights': 'distance'}
# ----- train score -----
# 1.0
# f2 score :  1.0
# ----- test score -----
# 0.75
# f1 score :  0.75
# f2 score :  0.75
#
#               precision    recall  f1-score   support
#
#    Disease 0       0.67      0.67      0.67         3
#    Disease 1       0.75      0.75      0.75         4
#
#     accuracy                           0.71         7
#    macro avg       0.71      0.71      0.71         7
# weighted avg       0.71      0.71      0.71         7
#
# ----- confusion matrix -----
# [[11  2]
#  [ 0 13]]
# accuracy 0.9230769230769231
# precision 0.8666666666666667
# recall 1.0
# f1 score :  0.9285714285714286
# f2 score :  0.9701492537313434

# %%
pair_list = ['EP0573','EP0567','EP0555','EP0547','EP0530','EP0527','EP0511','EP0510','EP0465','EP0456','EP0450','EP0439','EP0437','EP0546'] # EP0546 이 없는 데이터
pair_list = ['EP0573','EP0567','EP0555','EP0547','EP0530','EP0527','EP0511','EP0510','EP0465','EP0456','EP0450','EP0439','EP0437']
TG_data = pd.read_excel("./Data/-_210122.xlsx",sheet_name=1)
TG_data=TG_data.rename(columns=TG_data.iloc[0])
TG_data=TG_data.drop(TG_data.index[0])

pair_data = TG_data[TG_data['Subject ID\n(병원코드)'].isin(pair_list)].iloc[:,:-3]

pair_data['ADT/ART']=0
pair_data['연구실코드']=pair_data['연구실코드'].apply(lambda x: x[:3]).copy()
pair_data['ADT/ART']=pair_data['연구실코드'].apply(lambda x: 0 if x=='ART'else 1)

from scipy.stats import ttest_ind, shapiro, mannwhitneyu, levene, kstest, f_oneway
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
from scipy import interp
from sklearn.svm import SVC
from sklearn.metrics import roc_auc_score


Cat1 = pair_data[pair_data['ADT/ART']==1]
Cat2 = pair_data[pair_data['ADT/ART']==0]

for column in pair_data.columns.to_list()[5:-1]:
    X = np.array(pair_data[column]).reshape(-1,1)
    y = pair_data.loc[:, 'ADT/ART'].values
    random_state = np.random.RandomState(0)
    model = OneVsRestClassifier(SVC(kernel='linear', probability=True,random_state=random_state))

    model.fit(X,y)
    y_score=model.decision_function(X)
    fpr, tpr, _ = roc_curve(y, y_score)

    fig,ax = plt.subplots(1,2,figsize=(15,5))
    plt.suptitle('{} boxplot'.format(column))
    ax[0].boxplot((Cat1[column].to_numpy(),Cat2[column].to_numpy()),sym="o", labels=["ADT","ART"])
    ax[1].plot(fpr, tpr, color='darkorange',lw=2,label='ROC curve')
    plt.show()
    
    print("\n ROC Curve : %f \n "%roc_auc_score(y, y_score),end='\n\n')    
    print("\n T-test-statistic : %f \n p-value : %f"%ttest_ind(Cat1[column], Cat2[column]),end='\n\n') # 데이터가 평균 차이를 갖는가
    print("\n 대조군 Shapiro-Wilk-statistic : %f \n p-value : %f"%shapiro(Cat1[column]),end='\n\n') # 정규성을 갖는가
    print("\n 질환군 Shapiro-Wilk-statistic : %f \n p-value : %f"%shapiro(Cat2[column]),end='\n\n') 
    print("\n Mann-Whitney-statistic : %f \n p-value : %f"%mannwhitneyu(Cat1[column], Cat2[column]),end='\n\n') # 데이터가 순위합 차이를 갖는가
    print("\n Levene-statistic : %f \n p-value : %f"%levene(Cat1[column], Cat2[column]),end='\n\n') # 이분산 < p-value 0.05 < 등분산 
#   print("\n 대조군 Kolmogorov-Smirnov -statistic : %f \n p-value : %f"%kstest(Cat1[column],'norm'),end='\n\n')
#   print("\n 질환군 Kolmogorov-Smirnov -statistic : %f \n p-value : %f"%kstest(Cat2[column],'norm'),end='\n\n')
# Out:
#  ROC Curve : 0.585799
#
#
#
#  T-test-statistic : 1.083540
#  p-value : 0.289335
#
#
#  대조군 Shapiro-Wilk-statistic : 0.964676
#  p-value : 0.823714
#
#
#  질환군 Shapiro-Wilk-statistic : 0.945662
#  p-value : 0.534240
#
#
#  Mann-Whitney-statistic : 70.000000
#  p-value : 0.236394
#
#
#  Levene-statistic : 0.020674
#  p-value : 0.886872
#  ROC Curve : 0.769231
#
#
#
#  T-test-statistic : 2.533611
#  p-value : 0.018234
#
#
#  대조군 Shapiro-Wilk-statistic : 0.960849
#  p-value : 0.766723
#
#
#  질환군 Shapiro-Wilk-statistic : 0.951382
#  p-value : 0.619376
#
#
#  Mann-Whitney-statistic : 39.000000
#  p-value : 0.010508
#
#
#  Levene-statistic : 2.668759
#  p-value : 0.115387
#  ROC Curve : 0.639053
#
#
#
#  T-test-statistic : 1.580463
#  p-value : 0.127091
#
#
#  대조군 Shapiro-Wilk-statistic : 0.962662
#  p-value : 0.794166
#
#
#  질환군 Shapiro-Wilk-statistic : 0.904893
#  p-value : 0.156087
#
#
#  Mann-Whitney-statistic : 61.000000
#  p-value : 0.119102
#
#
#  Levene-statistic : 0.000011
# ...
