# %% [markdown]
# # Hello World!
# 간단한 colab notebook 팁

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
#@title 입력필드 form 만들기
#@markdown 한 셀이 길어지는 경우, ```#@title``` 사용하여 셀 접을 수 있음 \
#@markdown title로 목차에서 바로바로 찾을 수 있음

no_type_checking = ''  #@param
string_type = 'example'  #@param {type: "string"}
slider_value = 142  #@param {type: "slider", min: 100, max: 200}
number = 102  #@param {type: "number"}
#@markdown ---
#@markdown <i>```중간에 markdown 삽입하기```
#@markdown ---
date = '2010-11-05'  #@param {type: "date"}
pick_me = "monday"  #@param ['monday', 'tuesday', 'wednesday', 'thursday']
select_or_input = "apples" #@param ["apples", "bananas", "oranges"] {allow-input: true}
#@markdown ---

# %%
#@title 연결끊김방지
#@markdown 실행하면 javascript function 실행
#@markdown ```javascript
#@markdown function ClickConnect(){
#@markdown     console.log("Working");
#@markdown     document.querySelector("colab-toolbar-button#connect").click()
#@markdown }setInterval(ClickConnect,30000)
#@markdown ```

# %%javascript
function ClickConnect(){
    console.log("Working"); 
    document.querySelector("colab-toolbar-button#connect").click() 
}setInterval(ClickConnect,30000)

# %%
#@title Magic Command %%writefile
#@markdown .py로 되어있는 파일 수정이 필요한 경우, notebook에서 수정하고 %%writefile하면 좋음
# %%writefile ls.sh
ls -al
# Out:
# Writing ls.sh

# %%
#@title Magic Command %%bash
#@markdown %%writefile 실행하는 것도 좋음
#@markdown !bash ./ls.sh 랑 동일
# %%bash
bash ./ls.sh
# Out:
# total 20
# drwxr-xr-x 1 root root 4096 Mar  7 05:55 .
# drwxr-xr-x 1 root root 4096 Mar  7 05:20 ..
# drwxr-xr-x 1 root root 4096 Feb 18 14:33 .config
# -rw-r--r-- 1 root root    6 Mar  7 05:55 ls.sh
# drwxr-xr-x 1 root root 4096 Feb 18 14:33 sample_data

# %%
#셀의 우측 상단의 메뉴에서 탭에서 셀 미러링을 잘 사용하자
# Out:
# total 20
# drwxr-xr-x 1 root root 4096 Mar  7 05:55 .
# drwxr-xr-x 1 root root 4096 Mar  7 05:20 ..
# drwxr-xr-x 1 root root 4096 Feb 18 14:33 .config
# -rw-r--r-- 1 root root    6 Mar  7 05:55 ls.sh
# drwxr-xr-x 1 root root 4096 Feb 18 14:33 sample_data

# %% [markdown]
# ctrl + shift + "p" -> 명령어 팔레트

# %% [markdown]
# ctrl + alt + 'n' -> 스크레치 셀 열기

# %% [markdown]
# [VS Code와 Colab 연결하기](https://https://medium.com/geekculture/how-to-use-google-colab-with-vs-code-8d4876def8ed)
#
# vs code에서 colab 자원만 활용하기

# %%
#@title colab에 파일 업로드
#@markdown 드래그앤드롭 가능
from google.colab import files

uploaded = files.upload()
